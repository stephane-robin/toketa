# %% [markdown]
# # Découvrir les variables par la pratique

# %% [markdown]
# *Rappel : pour exécuter une cellule de code, taper SHIFT + ENTREE.*

# %% [markdown]
# ## Qu'est-ce qu'une variable ?

# %% [markdown]
# Une variable est un objet informatique composé d'un nom, d'une valeur, d'une adresse et d'un type.
# - le nom doit être explicite, ne peut pas être composé d'une instruction Python, ne peut pas commencer par un chiffre
# - la valeur d'une variable est amenée à changer au cours de l'exécution d'un programme
# - l'adresse de la variable permet de la retrouver en mémoire
# - le type correspond à la famille de cette variable et permet de lui fournir une structure qui répond à ses besoins

# %% [markdown]
# ## Comment définir une variable ?

# %% [markdown]
# On définit la valeur d'une variable avec un signe `=` comme dans l'exemple ci-dessous :

# %%
age = 16

# %% [markdown]
#  On pourra par la suite lui donner de nouvelles valeurs autant de fois que nécessaires.

# %% [markdown]
# ***A toi de jouer:***
# Exécute le code ci-dessous et trouve dans quel cas on doit mettre les guillemets.

# %%
age = 6
nouvel_age = age + 1
print(nouvel_age)

age = "6"
expression = age + " ans"
print(expression)

# %% [markdown]
# ***A toi de jouer :***
# Exécute la cellule ci-dessous et trouve les 4 principaux types simples de variables en Python.

# %%
print(type("bonjour"))
print(type(25))
print(type(17.5))
print(type(True))

# %% [markdown]
# ## Comment utiliser une variable ?

# %% [markdown]
# On utilise une variable en l'appelant par son nom et le programme remplacera ce nom par sa valeur, comme dans l'exemple ci-dessous, où `identite` prend la valeur `Antoine - Robert` :

# %%
prenom = "Antoine"
nom = "Robert"
identite = nom + " - " + prenom

# %% [markdown]
# ***A toi de jouer :***
# Ecris un code dans la cellule ci-dessous, qui définit une variable `age` en lui donnant la valeur 16 et une variable `pseudo` en lui donnant la valeur `sharkrunner`. Construis ensuite un mot de passe en écrivant bout à bout les deux variables précédentes.

# %%
# ton code ici

# %% [markdown]
# ## Les principales opérations

# %% [markdown]
# - `+` pour l'addition
# - `-` pour la soustraction
# - `*` pour la multiplication
# - `**` pour la puissance
# - `/` pour la division
# - `//` pour le quotient de division
# - `%` pour le reste de division

# %% [markdown]
# ***A toi de jouer :***
# Exécute chacun des codes ci-dessous et explique ce qu'ils calculent.

# %%
7 + 2

# %%
4 - 3

# %%
5 * 3

# %%
3 ** 2

# %%
5 / 2

# %%
5 // 2

# %%
5 % 2

# %% [markdown]
# ## Comment afficher une variable ?

# %% [markdown]
# On utilise l'instruction print() et le nom de la variable. Par exemple, exécute le code suivant qui affiche `Hervé a 17 ans` :

# %%
prenom = "Hervé"
age = "17"
print(prenom + " a " + age + " ans")

# %% [markdown]
# ***A toi de jouer :***
# Ecris un code dans la cellule ci-dessous qui donne la valeur `Lucie` à la variable `prenom`, puis qui affiche `Bonjour Lucie` en utilisant dans le code `prenom` au lieu de sa valeur `Lucie`.

# %%
# ton code ici
